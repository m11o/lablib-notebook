# %%
import numpy as np
import pandas as pd

from utils.context_data_csv import ContextDataCSV
from utils.matrix_optimizer import MatrixOptimizer
import utils.sulfur.constant as const

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./resources/freezing_data/ID181106CreA/A2.csv', index_col=[0], header=[0])
df
# Out:
#          X    Y  AREA   XOR  FZ  conseq FZ  Distance  Tone  Shock  Light
# Slice
# 0      104  166  1578     0   1          0       0.0     0      0      0
# 1      118  167  1208   710   0          0       1.5     1      0      0
# 2      116  154  1193   654   0          0       1.6     1      0      0
# 3      114  139  1441   701   0          0       1.9     1      0      0
# 4      120  133  1686   237   0          0       1.0     1      0      0
# ...    ...  ...   ...   ...  ..        ...       ...   ...    ...    ...
# 3616   199   77  1686  1138   0          0       2.6     1      0      0
# 3617   234   59  1682  1839   0          0       4.5     1      0      0
# 3618   261   52  1401  1252   0          0       3.2     1      0      0
# 3619   254   63  1370   844   0          0       1.6     1      0      0
# 3620   255   76  1222   991   0          0       1.6     1      0      0
#
# [3621 rows x 10 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 4), dpi=200)

x = df.index
freezing_value = df.loc[:, 'FZ'].copy(deep=True)
freezing_value = freezing_value[]
ax.plot(x, df.loc[:, 'Tone'], color='yellowgreen', alpha=0.5, label='Tone')
ax.plot(x, , label='Freezing')
ax.set_xticks(range(0, len(df) + 1, 100))
ax.set_xticklabels(list(range(0, len(df) + 1, 100)), rotation=45)
fig.show()
