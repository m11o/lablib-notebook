# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
all_event_rate_df = pd.read_csv('./resources/event_rates/oasis_by_cells/all_event_rates_threshold03.csv', index_col=[0], header=[0])
engram_event_rate_df = pd.read_csv('./resources/event_rates/oasis_by_cells/engram_event_rates_threshold03.csv', index_col=[0], header=[0])
non_engram_event_rate_df = pd.read_csv('./resources/event_rates/oasis_by_cells/non_engram_event_rates_threshold03.csv', index_col=[0], header=[0])

# %%
all_event_rate_df
# Out:
#                    HC1   A1preES  A1postES       HC2       HC3      A2_1  \
# ID181106CreA  0.495442  0.376323  0.489600  0.544549  0.385631  0.370550
# ID181106CreB  0.358155  0.354356  0.391833  0.398276  0.419518  0.442858
# ID181106CreC  0.146609  0.223409  0.291381  0.187830  0.171058  0.313291
# ID181106CreG  0.429910  0.245960  0.339476  0.311142  0.328377  0.318837
# ID181106CreH  0.169618  0.303809  0.441843  0.307999  0.365101  0.255428
# ID181106CreI  0.480397  0.367749  0.366612  0.485911  0.326666  0.397656
# ID181106CreK  0.274689  0.371242  0.352798  0.462924  0.289029  0.369701
# ID181106CreL  0.207952  0.219911  0.322238  0.316636  0.232001  0.326325
# ID181106CreN  0.310607  0.374548  0.350869  0.331694  0.278463  0.315693
# ID181106CreQ  0.315862  0.314278  0.330718  0.394953  0.283323  0.372889
#
#                   A2_2      A3_1      A3_2        B1       HC4   A4preES  \
# ID181106CreA  0.631700  0.379650  0.506242  0.425829  0.293007  0.540071
# ID181106CreB  0.513440  0.374896  0.412379  0.309572  0.411415  0.401120
# ID181106CreC  0.343264  0.268908  0.393979  0.241875  0.168947  0.476305
# ID181106CreG  0.341982  0.375758  0.509002  0.241627  0.376288  0.369784
# ID181106CreH  0.385025  0.296835  0.441993  0.301752  0.283574  0.366795
# ID181106CreI  0.611518  0.412202  0.653341  0.560671  0.321651  0.679182
# ID181106CreK  0.433668  0.409116  0.506349  0.441470  0.258011  0.515078
# ID181106CreL  0.339130  0.322942  0.427414  0.258834  0.332878  0.313244
# ID181106CreN  0.396667  0.309402  0.387731  0.360198  0.277987  0.353096
# ID181106CreQ  0.439051  0.366086  0.449970  0.349844  0.391010  0.434300
#
#               A4postES       HC5       HC6        A5        B2
# ID181106CreA  0.516932  0.395859  0.286642  0.762928  0.367644
# ID181106CreB  0.428424  0.485985  0.315078  0.498009  0.421143
# ID181106CreC  0.614910  0.265547  0.209922  0.600804  0.282696
# ID181106CreG  0.410921  0.387781  0.535800  0.607203  0.245424
# ID181106CreH  0.440719  0.289149  0.353246  0.557196  0.233168
# ID181106CreI  0.559983  0.416329  0.326086  0.696970  0.347721
# ID181106CreK  0.469612  0.513965  0.259227  0.506909  0.402804
# ID181106CreL  0.306367  0.286250  0.355293  0.396688  0.281787
# ID181106CreN  0.526763  0.334739  0.219952  0.506829  0.413545
# ID181106CreQ  0.349793  0.385625  0.340160  0.462464  0.295468

# %%
print(len(all_event_rate_df.columns))
print(len(all_event_rate_df.mean()))
print(len(all_event_rate_df.sem()))
# Out:
# 17
# 17
# 17

# %%
x = all_event_rate_df.columns.to_numpy()
y = all_event_rate_df.mean().to_numpy()
error = all_event_rate_df.sem().to_numpy()

plt.rcParams["font.size"] = 22
plt.figure(figsize=(25, 10))
plt.errorbar(x, y, yerr=error, capsize=2)
plt.plot(x, y, marker="s", markersize=12, markeredgewidth=3, color='royalblue')
plt.ylim(0, 1.5)
plt.ylabel('Ca2+ Event Rate (Hz)')
plt.tight_layout()
plt.show()

# %%
engram_x = engram_event_rate_df.columns
engram_y = engram_event_rate_df.mean()
engram_err = engram_event_rate_df.sem()

non_engram_x = non_engram_event_rate_df.columns
non_engram_y = non_engram_event_rate_df.mean()
non_engram_err = non_engram_event_rate_df.sem()

plt.rcParams["font.size"] = 22
plt.figure(figsize=(25, 10))

plt.errorbar(engram_x, engram_y, yerr=engram_err, capsize=2)
plt.plot(engram_x, engram_y, marker="s", markersize=12, markeredgewidth=3, label='engram cell', color='royalblue')

plt.errorbar(non_engram_x, non_engram_y, yerr=non_engram_err, capsize=2)
plt.plot(non_engram_x, non_engram_y, marker="s", markersize=12, markeredgewidth=3, label='non-engram cell', color='tomato')

plt.ylim(0, 1.5)
plt.ylabel('Calcium Event Rate (Hz)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
x = all_event_rate_df.columns.to_numpy()
y = all_event_rate_df.mean().to_numpy()
error = all_event_rate_df.sem().to_numpy()

engram_x = engram_event_rate_df.columns
engram_y = engram_event_rate_df.mean()
engram_err = engram_event_rate_df.sem()

non_engram_x = non_engram_event_rate_df.columns
non_engram_y = non_engram_event_rate_df.mean()
non_engram_err = non_engram_event_rate_df.sem()

fig, aix = plt.subplots(2, figsize=(25, 15), tight_layout=True, sharex='all')

aix[0].errorbar(x, y, yerr=error, capsize=2)
aix[0].plot(x, y, marker="s", markersize=12, markeredgewidth=3, color='royalblue')
aix[0].set_ylim(0, 1.5)
aix[0].set_ylabel('Ca2+ Event Rate (Hz)')
aix[0].set_title('Ca2+ event rates (threshold: 0.05)')

aix[1].errorbar(engram_x, engram_y, yerr=engram_err, capsize=2)
aix[1].plot(engram_x, engram_y, marker="s", markersize=12, markeredgewidth=3, label='engram cell', color='royalblue')

aix[1].errorbar(non_engram_x, non_engram_y, yerr=non_engram_err, capsize=2)
aix[1].plot(non_engram_x, non_engram_y, marker="s", markersize=12, markeredgewidth=3, label='non-engram cell', color='tomato')
aix[1].set_ylim(0, 1.5)
aix[1].set_ylabel('Ca2+ Event Rate (Hz)')
aix[1].set_title('Ca2+ event rates with engram (threshold: 0.05)')
aix[1].legend(loc='lower right')

plt.xticks(rotation=45)

# plt.show()
plt.savefig('./resources/event_rates/figure_threshold005.png')
