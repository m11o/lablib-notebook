# %%
from utils.TimeCorrelationCalculator import TimeCorrelationCalculator
from utils.TimeCorrelationViewer import TimeCorrelationViewer

# %%
def file_path_builder(animal_name):
    return './resources/%s_Longitudinal_Traces.csv' % animal_name

# %%
animal_name = 'ID181106CreA'
context_name = 'A1preES'
file_path = file_path_builder(animal_name)

calculator = TimeCorrelationCalculator(file_path)
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:1843: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
# A1preES: 0.0-40s
corr_df_for_all, corr_df_for_engram, corr_df_for_non_engram = calculator.calc(context_name=context_name, start=0, end=40)

viewer = TimeCorrelationViewer(corr_df_for_all, corr_df_for_engram, corr_df_for_non_engram)
# viewer.view_correlation_colormesh()
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

# %%
context_name = 'A1postES'

# A1postES: 0.0-220s
result = calculator.calc(context_name=context_name, start=0, end=220)

viewer = TimeCorrelationViewer(*result)
# viewer.view_correlation_colormesh()
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

# %%
# A1postES: 0-40s
result = calculator.calc(context_name=context_name, start=0, end=40)
viewer = TimeCorrelationViewer(*result)
#viewer.view_correlation_colormesh()
#viewer.view_sum_of_correlation_bar()
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

# A1postES: 90-130s
result = calculator.calc(context_name=context_name, start=90, end=130)
viewer = TimeCorrelationViewer(*result)
#viewer.view_correlation_colormesh()
#viewer.view_sum_of_correlation_bar()
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

# A1postES: 180-220s
result = calculator.calc(context_name=context_name, start=180, end=220)
viewer = TimeCorrelationViewer(*result)
#viewer.view_correlation_colormesh()
#viewer.view_sum_of_correlation_bar()
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

# %%
context_name = 'A2_1'

# A2: 0-40s
result = calculator.calc(context_name=context_name, start=0, end=40)
viewer = TimeCorrelationViewer(*result)
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

# %%
context_name = 'A2_2'

# A2: ~end
result = calculator.calc(context_name=context_name, start=260, end=300)
viewer = TimeCorrelationViewer(*result)
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

# %%
context_name = 'B1'

# B1: 0-40s
result = calculator.calc(context_name=context_name, start=0, end=40)
viewer = TimeCorrelationViewer(*result)
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

# B1: ~end
result = calculator.calc(context_name=context_name, start=260, end=300)
viewer = TimeCorrelationViewer(*result)
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

# %%
context_name = 'A4postES'

# A4postES: 0.0-220s
result = calculator.calc(context_name=context_name, start=0, end=220)

viewer = TimeCorrelationViewer(*result)
# viewer.view_correlation_colormesh()
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()
# Out:
# /opt/conda/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 21.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 19.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
context_name = 'A4preES'

# A4preES: 0-40s
result = calculator.calc(context_name=context_name, start=0, end=40)
viewer = TimeCorrelationViewer(*result)
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

context_name = 'A4postES'

# A4postES: 0-40s
result = calculator.calc(context_name=context_name, start=0, end=40)
viewer = TimeCorrelationViewer(*result)
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

# A4postES: 90-130s
result = calculator.calc(context_name=context_name, start=90, end=130)
viewer = TimeCorrelationViewer(*result)
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

# A4postES: 180-220s
result = calculator.calc(context_name=context_name, start=180, end=220)
viewer = TimeCorrelationViewer(*result)
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

# %%
context_name = 'A5'

# A5: 0-40s
result = calculator.calc(context_name=context_name, start=0, end=40)
viewer = TimeCorrelationViewer(*result)
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

# A5: ~end
result = calculator.calc(context_name=context_name, start=260, end=300)
viewer = TimeCorrelationViewer(*result)
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

# %%
context_name = 'B2'

# B2: 0-40s
result = calculator.calc(context_name=context_name, start=0, end=40)
viewer = TimeCorrelationViewer(*result)
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

# B2: ~end
result = calculator.calc(context_name=context_name, start=260, end=300)
viewer = TimeCorrelationViewer(*result)
viewer.view_heatmap()
viewer.view_sum_of_correlation_bar()

# %%
import numpy as np
import pandas as pd
df1 = pd.DataFrame(np.random.randn(5,5), columns=list(range(1,6))).assign(Trial=1)
df2 = pd.DataFrame(np.random.randn(5,5), columns=list(range(1,6))).assign(Trial=2)
df3 = pd.DataFrame(np.random.randn(5,5), columns=list(range(1,6))).assign(Trial=3)

cdf = pd.concat([df1, df2, df3]) 
print(cdf)
mcf = pd.melt(cdf, id_vars=['Trial'], var_name=['Number']) 
print(mcf)

series1 = pd.Series(np.arange(1, 4))
df4 = pd.DataFrame(series1).assign(Trial=4)
df4
# Out:
#           1         2         3         4         5  Trial
# 0  0.192264  1.716918  0.665003  0.455536 -0.093257      1
# 1  0.844335 -1.583330  0.033719  0.335577  0.985812      1
# 2  2.049241  0.503906 -0.435921  0.026291  1.194021      1
# 3 -1.196277 -0.459794 -0.460029  1.549834  1.635184      1
# 4  0.092653 -0.056732  0.958927 -0.078164  1.528553      1
# 0 -0.758879 -0.103086  0.391532 -1.057975  0.919559      2
# 1  0.712584 -0.670753  0.959600  0.141687 -1.265256      2
# 2 -0.237268 -0.414403  1.729129  0.548962  0.081010      2
# 3  0.835776 -0.820864  0.256715  1.603851  0.356270      2
# 4 -1.169308  0.452532 -0.535599  0.051889  0.984728      2
# 0 -0.082674 -2.231012  0.580627 -0.110176  0.004204      3
# 1 -0.809092  0.755232 -0.537535  0.804229 -2.056531      3
# 2  0.079794  0.640020  0.387651 -0.995981 -1.149498      3
# 3 -0.947246 -0.180293 -0.253586 -0.147531  0.664525      3
# 4  2.226106  0.096572  0.573240  0.642108  0.790323      3
# ...
